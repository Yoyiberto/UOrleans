# %%
import numpy as np 
from tensorflow import keras 
from tensorflow.keras import layers 
# Model and data parameters 
num_classes = 10  # 10 classes for digits 0-9 
input_shape = (28, 28, 1)  # Image dimensions (28x28, 1 grayscale channel) 
# Load the MNIST data, split between train and test sets 
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data() 
# Normalize images to values between 0 and 1 
x_train = x_train.astype("float32") / 255 
x_test = x_test.astype("float32") / 255 
 
# Reshape data to include the channel dimension for CNN 
x_train = np.expand_dims(x_train, -1) 
x_test = np.expand_dims(x_test, -1) 
 
# Print dataset shapes 
print("x_train shape:", x_train.shape) 
print(x_train.shape[0], "training samples") 
print(x_test.shape[0], "test samples") 
 
# Convert labels to one-hot encoding 
y_train = keras.utils.to_categorical(y_train, num_classes) 
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 8s 1us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 training samples
# 10000 test samples

# %%
# Build the Sequential model with Keras 
model = keras.Sequential( 
    [ 
        keras.Input(shape=input_shape), 
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"), 
        layers.MaxPooling2D(pool_size=(2, 2)), 
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"), 
        layers.MaxPooling2D(pool_size=(2, 2)), 
        layers.Flatten(), 
        layers.Dropout(0.5), 
        layers.Dense(num_classes, activation="softmax"), 
    ] 
)

# %%
batch_size = 128 
epochs = 15 
# Compile the model 
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"]) 
# Train the model 
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8951 - loss: 0.3575 - val_accuracy: 0.9777 - val_loss: 0.0841
# Epoch 2/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9664 - loss: 0.1100 - val_accuracy: 0.9850 - val_loss: 0.0560
# Epoch 3/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9741 - loss: 0.0834 - val_accuracy: 0.9873 - val_loss: 0.0461
# Epoch 4/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9783 - loss: 0.0706 - val_accuracy: 0.9885 - val_loss: 0.0416
# Epoch 5/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9803 - loss: 0.0625 - val_accuracy: 0.9895 - val_loss: 0.0411
# Epoch 6/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9821 - loss: 0.0570 - val_accuracy: 0.9898 - val_loss: 0.0391
# Epoch 7/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - accuracy: 0.9835 - loss: 0.0514 - val_accuracy: 0.9908 - val_loss: 0.0349
# Epoch 8/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9851 - loss: 0.0480 - val_accuracy: 0.9918 - val_loss: 0.0322
# Epoch 9/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9854 - loss: 0.0454 - val_accuracy: 0.9918 - val_loss: 0.0307
# Epoch 10/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9872 - loss: 0.0404 - val_accuracy: 0.9922 - val_loss: 0.0321
# Epoch 11/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9878 - loss: 0.0386 - val_accuracy: 0.9895 - val_loss: 0.0392
# Epoch 12/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - accuracy: 0.9879 - loss: 0.0380 - val_accuracy: 0.9913 - val_loss: 0.0286
# Epoch 13/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9882 - loss: 0.0371 - val_accuracy: 0.9918 - val_loss: 0.0298
# Epoch 14/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9887 - loss: 0.0354 - val_accuracy: 0.9910 - val_loss: 0.0295
# Epoch 15/15
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9897 - loss: 0.0315 - val_accuracy: 0.9920 - val_loss: 0.0286

# %%
score = model.evaluate(x_test, y_test, verbose=0) 
print("Test loss:", score[0]) 
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.023499760776758194
# Test accuracy: 0.9921000003814697
